# %%
import tkinter as tk


root = tk.Tk()
root.title = 'Title of window'
my_entry = tk.Entry(root, width=50)
my_entry.pack()
my_entry.insert(0, 'Enter your name')
 
def clickHandler():
    hello = 'Hello '+my_entry.get()
    my_label = tk.Label(root, text='Hello '+my_entry.get())
    my_label.pack()

my_button = tk.Button(root, text='Click me', command=clickHandler, fg='white', bg='black')

my_button.pack()

root.mainloop()

# %%
#

import tkinter as tk

root = tk.Tk()
root.title('Registeration Form')
root.geometry('600x600')


headerLabel = tk.Label(root, text='Gateways').grid(row=0, columnspan=4)

collegeName = tk.StringVar()

collegeLabel = tk.Label(root, text='Enter college name: ').grid(row=1, column=0)
collegeEntry = tk.Entry(root, textvariable=collegeName).grid(row=1, column=1)

nameLabel = tk.Label(root, text='Enter name: ').grid(row=2, column=0)
nameEntry = tk.Entry(root).grid(row=2, column=1)

contactLabel = tk.Label(root, text='Enter contact no: ').grid(row=3, column=0)
contactEntry = tk.Entry(root).grid(row=3, column=1)

participantsLabel = tk.Label(root, text='Enter no. of participants: ').grid(row=4, column=0)
participantEntry = tk.Entry(root).grid(row=4, column=1)

eventList = tk.Label(root, text='Select events: ').grid(row=5, column=0)
Checkbutton1 = tk.BooleanVar()
Checkbutton2 = tk.BooleanVar()
Checkbutton3 = tk.BooleanVar()
Checkbutton4 = tk.BooleanVar()
Checkbutton5 = tk.BooleanVar()
Checkbutton6 = tk.BooleanVar()
Checkbutton7 = tk.BooleanVar()
Checkbutton8 = tk.BooleanVar()


check1 = tk.Checkbutton(root, text = "Event123", 
                    variable=Checkbutton1,
                      height = 2,
                      width = 10).grid(row=6, column=0)
check2 = tk.Checkbutton(root, text = "Event", 
                    variable=Checkbutton2,
                      height = 2,
                      width = 10).grid(row=6, column=1)
check3 = tk.Checkbutton(root, text = "Event", 
                    variable=Checkbutton3,
                      height = 2,
                      width = 10).grid(row=6, column=2)
check4 = tk.Checkbutton(root, text = "Event", 
                    variable=Checkbutton4,
                      height = 2,
                      width = 10).grid(row=6, column=3)
check5 = tk.Checkbutton(root, text = "Event", 
                    variable=Checkbutton5,
                      height = 2,
                      width = 10).grid(row=7, column=0)
check6 = tk.Checkbutton(root, text = "Event", 
                    variable=Checkbutton6,
                      height = 2,
                      width = 10).grid(row=7, column=1)
check7 = tk.Checkbutton(root, text = "Event", 
                    variable=Checkbutton7,
                      height = 2,
                      width = 10).grid(row=7, column=2)
check8 = tk.Checkbutton(root, text = "Event", 
                    variable=Checkbutton8,
                      height = 2,
                      width = 10,
                      ).grid(row=7, column=3)

# res = tk.StringVar()


states = {
    "check1":False,
    "check2":False,
    "check3":False,
    "check4":False,
    "check5":False,
    "check6":False,
    "check7":False,
    "check8":False,
}

def getStates():
    states["check1"] = Checkbutton1.get()
    states["check2"] = Checkbutton2.get()
    states["check3"] = Checkbutton3.get()
    states["check4"] = Checkbutton4.get()
    states["check5"] = Checkbutton5.get()
    states["check6"] = Checkbutton6.get()
    states["check7"] = Checkbutton7.get()
    states["check8"] = Checkbutton8.get()
    

def checkEligibility():
    getStates()
    count = 0
    for chckButton in states:
       if states[chckButton] == True:
          count += 1
    if count < 5:
      res.set('Pls select min of 5 teams')  
    else:
      res.set('Valid')


registerButton = tk.Button(root, text='Register', padx=10, command=checkEligibility).grid(row=10, column=0, columnspan=4) 


res = tk.StringVar()
resultLablel = tk.Label(root, textvariable=res, font=('arial', 12)).grid(row=8, columnspan=4)

root.mainloop()

# %%
import tkinter as tk
 
root = tk.Tk(className='tk - TutorialKart', )
root.geometry("450x250")
 
check_1 = tk.IntVar()
check_2 = tk.IntVar()
check_3 = tk.IntVar()
 
def check1Clicked():
    if check_1.get() :
        print('Checkbox 1 selected')
    else :
        print('Checkbox 1 unselected')
 
def check2Clicked():
    if check_2.get() :
        print('Checkbox 2 selected')
    else :
        print('Checkbox 2 unselected')
 
def check3Clicked():
    if check_3.get() :
        print('Checkbox 3 selected')
    else :
        print('Checkbox 3 unselected')
 
check_but_1 = tk.Checkbutton(root, text = 'Listening to Music', variable = check_1,
                onvalue = 1, offvalue = 0, command=check1Clicked)
check_but_1.pack()
 
check_but_2 = tk.Checkbutton(root, text = 'Reading Books', variable = check_2,
                onvalue = 1, offvalue = 0, command=check2Clicked)
check_but_2.pack()
 
check_but_3 = tk.Checkbutton(root, text = 'Watching Movies', variable = check_3,
                onvalue = 1, offvalue = 0, command=check3Clicked)
check_but_3.pack()
 
root.mainloop()
# Out:
# Checkbox 1 selected
# Checkbox 1 unselected
# Checkbox 2 selected
