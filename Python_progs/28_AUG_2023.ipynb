# %% [markdown]
# ### Quantifiers
#
# ```*```  - 0 or more <br>
# ```+``` - 1 or more <br>
# ```?``` - 0 or one <br>
# ```{3}``` - Exact number <br>
# ```{3,4}``` - Range of numbers <br>

# %%
import re 


test_string = """
hello and welcome.
Phone No. : 9067607516
sometimes understanding this text can be different.


abcdefghijklmnopqrstuvwxyz
ABCDEFGHIJKLMNOPQRSTUVWXYZ

rowhittank@gmail.com


apple appleapple
Meta characters need to be escaped: 
/ | ? . { } [ ] ) ^ *



Mr. Schafer
Mr Davis
Mrs Smith
Mrs. Robinson
Mr. T

"""

sent = 'start a sentence and bring to an\
      end. lets try and figure out the \
        working.'

lookingThruNumbers = """
    800-121-533
    900-765-241
    cat
    mat
    hat
    bat
"""

random_emails = """
    https://www.google.com
http://rohit.com
http://healthcare.gov
https://www.youtube.com

"""




# pattern = re.compile(r'[89]00[-/]\d\d\d[-/]\d\d\d') 1
# pattern = re.compile(r'[89]00[-/]\d{3}[-/]\d{3}') 2
# pattern = re.compile(r'[^b]at') 3
# pattern = re.compile(r'Mr\.?\s[A-Z]') 4
# pattern = re.compile(r'Mr\.?\s[A-Z]\w*') 5
# word character after Mr. T (* hld 0 or more)
'''The dot in the pattern is and its question mark is covering whether it'''


# the above will only work for Mr and not Mrs. ----->

pattern = re.compile(r'(Mr|Ms|Mrs)\.?\s[A-Z]\w*')

# matches = pattern.finditer(test_string)

email_pattern = re.compile(r'https?://(www\.)?(\w+)(\.\w+)')
email_pattern = re.compile(r'https?://(www\.)?(\w+)(\.\w+)')

matches = email_pattern.finditer(random_emails)
subgroups = email_pattern.sub(r'\2\3', random_emails)

flags = re.compile(r'apple', re.IGNORECASE)
mat = flags.search(test_string) 
print(mat)

print(subgroups)
for match in matches:
    print(match.group(1))
# Out:
# <re.Match object; span=(175, 180), match='apple'>
#
#     google.com
# rohit.com
# healthcare.gov
# youtube.com
#
#
# www.
# None
# None
# www.
