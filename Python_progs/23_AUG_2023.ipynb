# %%
def getInput(user_input:str=''):
    while not user_input:
        user_input = input('Pls enter dob (dd/mm/yyyy): ')
    return user_input

user_input = input('Enter your dob(dd/mm/yyy): ')
if not user_input:
    user_input = getInput(user_input)

if user_input == '?':
    print('Enter your date of birth in (dd/mm/yyy) format.\n')
    print('Example: 26/12/2001')
    user_input = getInput()



user_dob = input('Enter your dob in dd/mm/yyy format: ')
if user_dob = 
while(user_dob.casefold() == 'q' or user_dob == '?' or not user_dob):
    if user_dob.casefold() == 'q':
        try:
            print('This is a user-defined exception')
        finally:
            print('Bye! Hope you run this program again.')

# %%
from datetime import datetime


def whats_the_input(user_input:str) -> str:
    while True:
        if user_input.casefold() == '?':
            print('\nYour date should be in format - dd/mm/yyy.\nExample: 12/12/2001.\nEnter again.')
            user_input = input()
            continue
        elif user_input.casefold() == 'q':
            try:
                print('\nBye! Hope you run this program again.')
            finally:
                break
        else:
            try:
                d, m, y = input('Enter your dob in dd/mm/yyy format: ').split('/')
                td, tm, ty = datetime.today().strftime("%d/%m/%Y").split('/')
                td, tm, ty = int(td), int(tm), int(ty)
                d, m, y = int(d), int(m), int(y)
                if ((30>=d or 31>=d)) and (12>=m) and ty>=y:
                    print('Age: ', ty - y)
                    user_input = input('\nEnter your dob in dd/mm/yyyy format: ')
            except ValueError:
                print('\nIncorrect dob format')
                user_input = '?'
            
                

whats_the_input(input('Enter your dob in dd/mm/yyyy format: '))
# Out:
# Incorrect dob format
#
# Your date should be in format - dd/mm/yyy.
# Example: 12/12/2001.
# Enter again.
#
# Incorrect dob format
#
# Your date should be in format - dd/mm/yyy.
# Example: 12/12/2001.
# Enter again.
#
# Incorrect dob format
#
# Your date should be in format - dd/mm/yyy.
# Example: 12/12/2001.
# Enter again.
#
# Incorrect dob format
#
# Your date should be in format - dd/mm/yyy.
# Example: 12/12/2001.
# Enter again.
#
# Incorrect dob format
#
# Your date should be in format - dd/mm/yyy.
# Example: 12/12/2001.
# Enter again.
#
# Incorrect dob format
#
# Your date should be in format - dd/mm/yyy.
# Example: 12/12/2001.
# Enter again.
#
# Incorrect dob format
#
# Your date should be in format - dd/mm/yyy.
# Example: 12/12/2001.
# Enter again.
#
# Your date should be in format - dd/mm/yyy.
# Example: 12/12/2001.
# Enter again.
#
# Your date should be in format - dd/mm/yyy.
# Example: 12/12/2001.
# Enter again.
#
# Your date should be in format - dd/mm/yyy.
# ...

# %%
d = input('Enter date dd/mm/yyy: ')
if d == "%d%d/%d%d/%d%d%d%d":
    print(True)

# %%
from datetime import datetime

def validate_date(d, m, y) -> [bool, int]:
    td, tm, ty = datetime.today().strftime("%d/%m/%Y").split('/')
    td, tm, ty = int(td), int(tm), int(ty)
    print(td, tm ,ty)
    d, m, y = input('Enter your dob in dd/mm/yyy format: ').split('/')
    d, m, y = int(d), int(m), int(y)


    if ((30>=d or 31>=d)) and (12>=m) and ty>=y:
        print('Age: ', ty - y)
        print(True)
    else: print(False)






def validate_date(d, m, y) -> [bool, int]:
    td, tm, ty = datetime.today().strftime("%d/%m/%Y").split('/')
    td, tm, ty = int(td), int(tm), int(ty)
    d, m, y = int(d), int(m), int(y)

    if ((30>=d or 31>=d)) and (12>=m) and ty>=y:
        return [True, ty-y]
    else: return [False]



d, m, y = input('Enter your dob in dd/mm/yyy format: ').split('/')


dob_input = input('Enter your dob in dd/mm/yyy format: ')
if not dob_input:
    dob_input = input('Pls enter your dob(dd/mm/yyyy): ')
elif dob_input.casefold == 'y':
    print('You need to enter you date of birth in dd/mm/yyyy format.')
    print('Example: 01/01/2000')
    dob_input = input('Now try again: ')
elif: user_dob. == 'q'
elif validate_date(d, m, y)[0]:
    year = datetime.today().strftime("%Y")
else:

# %%
rohit = ''
while True:
    if rohit == 'yes':
        quit()
    else: rohit = input('Enter yes/no: ')

# %%
from datetime import date

dob_prompt = "Your DOB (dd/mm/yyy)? "
dob_fmt = "dd/mm/yyyy"
dob_sep = "/"
dob_help_prompt = f"Please enter your DOB in the required format only; {dob_fmt}"
dob_quit_prompt = "Bye! Hope you run this program again"


def getAgeInYears(dob: date) -> int:
    return (date.today() - dob).days // 365


def wantsHelp(string: str) -> bool:
    return string.casefold() == "?"


def wantsToQuit(string: str) -> bool:
    return string.casefold() == "Q".casefold()


while True:
    dob = input(dob_prompt)

    if not dob:
        continue
    elif wantsHelp(dob):
        print(dob_help_prompt)
        continue
    elif wantsToQuit(dob):
        print(dob_quit_prompt)
        break
    else:
        try:
            dd, mm, yyyy = dob.split(dob_sep, maxsplit=3)
            dob = date(day=int(dd), month=int(mm), year=int(yyyy))

        except IndexError:
            print(dob_help_prompt)
            continue
        except ValueError:
            print(dob_help_prompt)
            continue
        else:
            print("You are", getAgeInYears(dob), "years old")
            break
