# %%
import pandas as pd
import matplotlib.pyplot as plt
#import searborn as sns
import seaborn as sns

movie = pd.read_csv(r'./csv_s/movies.csv')

animation = movie[movie['Genre'] == 'Animation']
comedy = movie[movie['Genre'] == 'Comedy']
romance = movie[movie['Genre'] == 'Romance']
drama = movie[movie['Genre'] == 'Drama']

numeric_columns = ['Audience score %', 'Profitability', 'Rotten Tomatoes %', 'Worldwide Gross']

# # Create a pair plot
sns.pairplot(movie[numeric_columns], diag_kind='kde')
plt.suptitle('Pair Plot of Numeric Columns', y=1.02)
plt.show()
# Out:
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
try:
    print(3/0)
except IndentationError:
    print('An error occured')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\test.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/d%3A/christUNI/MCA_sem1/dev1/College_Work/Python_progs/test.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> try:
# ----> <a href='vscode-notebook-cell:/d%3A/christUNI/MCA_sem1/dev1/College_Work/Python_progs/test.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a>     print(3/0)
#       <a href='vscode-notebook-cell:/d%3A/christUNI/MCA_sem1/dev1/College_Work/Python_progs/test.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> except IndentationError:
#       <a href='vscode-notebook-cell:/d%3A/christUNI/MCA_sem1/dev1/College_Work/Python_progs/test.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a>     print('An error occured')
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Matplotlib practice

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Scatterplot

# %%
df = pd.read_csv(r'./csv_s/movies.csv')
x = df['Profitability']
y = df['Audience score %']
plt.figure(figsize=(5,3))
plt.scatter(x, y, alpha=0.5)    
plt.title('Scatter plot of Profitability and Audience Score %')
plt.xlabel('Profitability')
plt.ylabel('Audience score %')
plt.show()

# %% [markdown]
# ### Bar Chart

# %%
# genre_avg_scores = df.groupby('Genre')['Audience Score %'].mean().reset_index()

print(movie[movie['Genre'] == 'Animation'].head())
# Create the bar chart
# plt.figure(figsize=(10, 4))
# plt.bar(genre_avg_scores['Genre'], genre_avg_scores['Audience Score %'])
# plt.title('Average Audience Score % by Genre')
# plt.xlabel('Genre')
# plt.ylabel('Average Audience Score   %')
# plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

# Show the plot
# plt.show()
# Out:
#                  Film      Genre Lead Studio  Audience score %  Profitability  \
# 6              WALL-E  Animation      Disney                89       2.896019
# 22            Tangled  Animation      Disney                88       1.365692
# 64  Gnomeo and Juliet  Animation      Disney                52       5.387972
# 65  Gnomeo and Juliet  Animation      Disney                52       5.387972
#
#     Rotten Tomatoes % Worldwide Gross    Year
# 6                  96        $521.28   2008.0
# 22                 89        $355.01   2010.0
# 64                 56        $193.97   2011.0
# 65                 56        $193.97   2011.0

# %%
# ignore - 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
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\christUNI\MCA_sem1\dev1\College_Work\Python_progs\test.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/christUNI/MCA_sem1/dev1/College_Work/Python_progs/test.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> pd['Lead Studio'].head(4)
#
# TypeError: 'module' object is not subscriptable

# %% [markdown]
# django-admin startproject web_project .
# python manage.py migrate
# python manage.py runserver
#
# python manage.py startapp hello
# python manage.py createsuperuser
# python manage.py migrate
#
# - make changes in hello/models.py
# - then makeprojects/settings.py
# -
